# %% [markdown]
# ## Programmatically close git project issues
# Make sure you know what you are doing.
#
# Manual:
# https://pygithub.readthedocs.io/en/latest/introduction.html

# %%
from datetime import date
today = date.today().strftime("%m/%d/%Y").replace('/','_')

# %%
# sanity test on my own guinea pig repo

import os
from github import Github

github = Github(os.environ['GITHUB_ACCESS_TOKEN'])

# init a repo obj
repo = github.get_repo('hsl89/test_doc_build')

# get all prs from the repo
issues = repo.get_issues(state='all')

with open('closed_issues_{}.txt'.format(today), 'w') as f:
    for iss in issues:
        # add a comment before closing
        iss.create_comment(
            "Dear SageMaker Community,\n \
            In our attempts to provide this repository with a better level of support \
            going forward, we’re closing issues that were opened prior to the v2 release of the SDK. \
            This is because we believe that over time many of the issues \
            posted were solved with the latest release or other recent changes to the repo. \
            This will help us reallocate resources towards issues that are\
            more likely to still be relevant today.\
            Some of the issues experienced now can be resolved by referencing the\
            v2 guide: https://sagemaker.readthedocs.io/en/stable/v2.html \
            In this guide, you can find simple solutions to common notebook errors, \
            like the renaming of parameters and classes.\
            If you believe your issue is still ongoing and you have updated error\
            messaging or other info, please re-open it, and we investigate the issue.\n\
            Best Regards,\n\
            AWS SageMaker Team")

        iss.edit(state='closed')

        f.write('{}\n'.format(iss.number))

# %% [markdown]
# ### Issues created before 2019

# %%
repo = github.get_repo('aws/amazon-sagemaker-examples')
issues = repo.get_issues(state='open')
before_2019 = [iss for iss in issues if iss.created_at.year < 2019]

print("Number of issues created (strictly) before 2019 Oct: {}".format(len(before_2019)))
# Out:
# Number of issues created (strictly) before 2019 Oct: 33

# %%
# real stuff

with open('closed_issues_{}.txt'.format(today), 'w') as f:
    for iss in before_2019:
        # add a comment before closing
        iss.create_comment(
            "Dear SageMaker Community,\n \
            In our attempts to provide this repository with a better level of support \
            going forward, we’re closing issues that were opened prior to the v2 release of the SDK. \
            This is because we believe that over time many of the issues \
            posted were solved with the latest release or other recent changes to the repo. \
            This will help us reallocate resources towards issues that are\
            more likely to still be relevant today.\
            Some of the issues experienced now can be resolved by referencing the\
            v2 guide: https://sagemaker.readthedocs.io/en/stable/v2.html \
            In this guide, you can find simple solutions to common notebook errors, \
            like the renaming of parameters and classes.\
            If you believe your issue is still ongoing and you have updated error\
            messaging or other info, please re-open it, and we investigate the issue.\n\
            Best Regards,\n\
            AWS SageMaker Team")

        iss.edit(state='closed')

        f.write('{}\n'.format(iss.number))

# %% [markdown]
# ### Some examples of those issues

# %%
with open('closed_issues_{}.txt'.format(today), 'r') as f:

# %%
# Out:
# [Issue(title="Delete.", number=553), Issue(title="Add a notebook example for deploying pre-trained TorchVision model with Neo", number=552), Issue(title="DeepAR - RMSE varying over 10% when retraining", number=551), Issue(title="Add end-to-end example for image classification.", number=550), Issue(title="Add inference pipeline sparkml xgboost car evaluation example", number=549), Issue(title="BYO model ", number=548), Issue(title="Add outputLocation parameter to RoboMaker call", number=547), Issue(title="{WIP} horovod notebook example and script mode notebook examples update.", number=546), Issue(title="Freeze framework mode TF notebooks to use 1.12", number=545), Issue(title="Add Batch Transform sample to  scikit Bring your own algorithm notebook", number=544), Issue(title="add setup.sh for tf script mode nb", number=534), Issue(title="tensorflow_script_mode_using_shell_commands fails", number=533), Issue(title="local training for tensorflow_script_mode_quickstart example fails ", number=532), Issue(title="Add vowel", number=531), Issue(title="AugmentedManifest Performance ~7-10x Lower Than LST File Mode for Built-In Classifier", number=530), Issue(title="Upgrade to use newest pytorch 1.0 version in pytorch examples.", number=529), Issue(title="Add example notebook for working with TFRecord data", number=528), Issue(title="tensorflow_bring_your_own out of date documentation.", number=527), Issue(title="Using Boto's RoboMaker Service Model for RoboMaker client creation", number=526), Issue(title="add a sample notebook for hpo early stopping", number=525), Issue(title="Sagemaker Batch Transform", number=524), Issue(title="remove unknown parameter with 'name' in input of robomaker.create_sim…", number=523), Issue(title="How to use GPU instances with my Bring Your Own PyTorch container", number=522), Issue(title="DeepAR : When to build new model", number=521), Issue(title="Loosing Tensorflow Graph in custom flask endpoint | Randomly working and then stop", number=520), Issue(title="ConnectionClosedError: Connection was closed before we received a valid response from endpoint URL", number=519), Issue(title="Add FAQ link to reinforcement learning folder", number=518), Issue(title="Sklearn docs 2018 12 11", number=517), Issue(title="bring_your_own Keras with callbacks", number=516), Issue(title="no examples for the api documentation", number=515), Issue(title="cannot install the MLeap JAR in EMR cluster", number=514), Issue(title="Update Image-classification-transfer-learning-highlevel.ipynb", number=513), Issue(title="remove redundant pip install", number=512), Issue(title="Use GPU instance for Neo Image Classification", number=511), Issue(title="Data file ID for the US Census by counties", number=510), Issue(title="fix deprecation warning", number=509), Issue(title="rl_deepracer_coach_robomaker Notebook - Faster S3 Copy", number=508), Issue(title="TensorFlow Script Mode bash example", number=507), Issue(title="Update README.md", number=506), Issue(title="Update train-coach.py", number=505), Issue(title="Adding RL Notebooks to the readme file.", number=504), Issue(title="Issue with AWS elastic Inference", number=503), Issue(title="DeepAR daily/weekly trends", number=502), Issue(title="Fixed: Link to scikit-learn inference pipeline didn't work", number=501), Issue(title="fix endpoint deletion", number=500), Issue(title="Update Ground Truth notebook for data analysis of image classificatio…", number=499), Issue(title="Adding copyright notice to RL notebooks.", number=498), Issue(title="add AWS DeepRacer sample application", number=497), Issue(title="add scikit product arns", number=496), Issue(title="Change m4 to c5 for RL ray example", number=495), Issue(title="Cartpole deployment fix", number=494), Issue(title="update README for portfolio example", number=493), Issue(title="Alter Scikit-learn notebook paths.", number=492), Issue(title="path fix for rl mountain car", number=491), Issue(title="Fix rl_traveling_salesman_vehicle_routin ...

# %%
repo.get_issue(number=211).milestone
